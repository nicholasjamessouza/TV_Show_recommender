# %%
import pandas as pd
from jikanpy import Jikan
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from matplotlib import pyplot as plt
import numpy as np
import os
import yaml
import ast
import difflib

jikan = Jikan()
columns = ['type','mal_id','title_english','popularity','rating','genres','studios','themes','demographics','synopsis']
file = './top_anime.csv'
pd.options.mode.chained_assignment = None  # default='warn'

# %%
def cell_splitter(temp_df):
    for i, values in enumerate(temp_df):
        if isinstance(values, str):
            values = yaml.load(values,Loader=yaml.Loader)
        value_list = []
        for value in values:
            value_list.append(value['name'])
        if len(values) == 1:
            value_list = value_list[0]
        temp_df.iloc[i] = value_list

    return temp_df

# %%
def nlp(text, num_of_words=10):
    text = text.values[0]
    cv = CountVectorizer(stop_words='english')
    dtm = cv.fit_transform([text])
    # Build LDA Model with GridSearch params
    lda_model = LatentDirichletAllocation(n_components=1,
                                        learning_decay=0.5,
                                        max_iter=50,
                                        learning_method='online',
                                        random_state=50,
                                        batch_size=100,
                                        evaluate_every = -1,
                                        n_jobs = -1)
    lda_output = lda_model.fit_transform(dtm)
    for topic in lda_model.components_:
        words = [cv.get_feature_names_out()[i] for i in topic.argsort()][-num_of_words:]
    return words

# %%
def anime_search(search,df=None):
    if df.empty:
        results = jikan.search('anime', search)
        df = pd.DataFrame(results['data'])
    else:
        search = search.lower()
        df[df['title'].str.contains(search)]
    temp_df = df[columns].dropna(),
    temp_df = temp_df[temp_df['type'] == 'TV']
    temp_df.drop('type',axis=1,inplace=True)
    temp_df.reset_index(drop=True)

    temp_df['genres'] = cell_splitter(temp_df['genres'])
    temp_df['studios'] = cell_splitter(temp_df['studios'])
    temp_df['themes'] = cell_splitter(temp_df['themes'])
    temp_df['demographics'] = cell_splitter(temp_df['demographics'])

    temp_df['synopsis'].iloc[0] = nlp(temp_df['synopsis'])

    return temp_df

# %%
def nlp(text, num_of_words=10):
    text = text.values[0]
    cv = CountVectorizer(stop_words='english')
    dtm = cv.fit_transform([text])
    # Build LDA Model with GridSearch params
    lda_model = LatentDirichletAllocation(n_components=1,
                                        learning_decay=0.5,
                                        max_iter=50,
                                        learning_method='online',
                                        random_state=50,
                                        batch_size=100,
                                        evaluate_every = -1,
                                        n_jobs = -1)
    lda_output = lda_model.fit_transform(dtm)
    for topic in lda_model.components_:
        words = [cv.get_feature_names_out()[i] for i in topic.argsort()][-num_of_words:]
    return words

# %%
def top_anime(pages=80):
    if pages==80 and os.path.exists(file):
        df = pd.read_csv(file,index_col=0)
    else:
        df = pd.DataFrame()
        for i in range(pages):
            results = jikan.top(type='anime',page=i)
            new_df = pd.DataFrame(results['data'])
            df = pd.concat([df,new_df], ignore_index=True)
            time.sleep(1)
        df.to_csv(file)

    pop_df = df[columns].dropna()
    pop_df = pop_df[pop_df['type'] == 'TV']
    pop_df.drop('type',axis=1,inplace=True)
    pop_df['genres'] = cell_splitter(pop_df['genres'])
    pop_df['studios'] = cell_splitter(pop_df['studios'])
    pop_df['themes'] = cell_splitter(pop_df['themes'])
    pop_df['demographics'] = cell_splitter(pop_df['demographics'])
    for j, synopsis in enumerate(pop_df['synopsis']):
        pop_df['synopsis'].iloc[j] = nlp(pd.Series(synopsis))

    return pop_df

# %%
fav_df = pd.DataFrame(columns = columns)
fav_df.drop('type',axis=1,inplace=True)
fav_anime = ['fullmetal alchemist: brotherhood','dragon ball z','steins;gate','psycho-pass','my hero academia','code geass: lelouch of','rurouni kenshin','attack on titan','madoka magica','one punch man']
search_df = None
sleep_timer = 1
if os.path.exists(file):
    search_df = pd.read_csv(file,index_col=0)
    sleep_timer = 0
for fav in fav_anime:
    print(fav)
    df = anime_search(fav, search_df)
    df.sort_values('popularity')
    temp_df = df.iloc[[0]]
    fav_df = pd.concat([fav_df,temp_df], ignore_index=True)
    time.sleep(sleep_timer)
fav_df
# Out:
# fullmetal alchemist: brotherhood
# dragon ball z
# steins;gate
# psycho-pass
# my hero academia
# code geass: lelouch of rebellion
# rurouni kenshin
# attack on titan
# puella magi madoka magica
# one punch man
#   mal_id                         title_english popularity  \
# 0   5114      Fullmetal Alchemist: Brotherhood          3
# 1    813                         Dragon Ball Z        104
# 2   9253                           Steins;Gate         13
# 3  13601                           Psycho-Pass         58
# 4  31964                      My Hero Academia          6
# 5   1575  Code Geass: Lelouch of the Rebellion         19
# 6     45                       Rurouni Kenshin        414
# 7  16498                       Attack on Titan          1
# 8   9756             Puella Magi Madoka Magica         94
# 9  30276                         One Punch Man          4
#
#                            rating                                    genres  \
# 0  R - 17+ (violence & profanity)       [Action, Adventure, Drama, Fantasy]
# 1       PG-13 - Teens 13 or older      [Action, Adventure, Comedy, Fantasy]
# 2       PG-13 - Teens 13 or older                 [Drama, Sci-Fi, Suspense]
# 3  R - 17+ (violence & profanity)                [Action, Sci-Fi, Suspense]
# 4       PG-13 - Teens 13 or older                                    Action
# 5  R - 17+ (violence & profanity)                   [Action, Drama, Sci-Fi]
# 6       PG-13 - Teens 13 or older      [Action, Adventure, Comedy, Romance]
# 7  R - 17+ (violence & profanity)  [Action, Award Winning, Drama, Suspense]
# 8       PG-13 - Teens 13 or older          [Award Winning, Drama, Suspense]
# 9  R - 17+ (violence & profanity)                          [Action, Comedy]
#
#                  studios                                  themes demographics  \
# 0                  Bones                                Military      Shounen
# 1         Toei Animation             [Martial Arts, Super Power]      Shounen
# 2              White Fox            [Psychological, Time Travel]           []
# 3         Production I.G  [Adult Cast, Detective, Psychological]           []
# 4                  Bones                   [School, Super Power]      Shounen
# 5                Sunrise  [Mecha, Military, School, Super Power]           []
# 6  [Gallop, Studio Deen]                   [Historical, Samurai]      Shounen
# 7             Wit Studio              [Gore, Military, Survival]      Shounen
# 8                  Shaft           [Mahou Shoujo, Psychological]           []
# 9               Madhouse       [Adult Cast, Parody, Super Power]       Seinen
#
#                                             synopsis
# 0  [rewrite, exchange, winry, elric, alchemist, a...
# 1  [annihilated, martial, balls, protect, warns, ...
# 2  [ire, using, caused, meets, send, friend, time...
# 3  [criminal, signs, jaded, akane, known, uphold,...
# 4  [months, chosen, prestigious, wanted, inherite...
# 5  [onslaught, rewrite, lamperouge, 11, area, jap...
# 6  [protecting, unmatched, kamiya, kaoru, years, ...
# 7  [born, join, shattered, enormous, titans, surv...
# 8  [sayaka, dreams, mal, madoka, kyuubey, akemi, ...
# 9  [member, capable, pursue, heroes, order, assoc...

# %%
pop_df_file = './pop_df.csv'
if os.path.exists(pop_df_file):
    pop_df = pd.read_csv(pop_df_file,index_col=0)
else:
    pop_df = top_anime()
    pop_df = pop_df.drop_duplicates(subset=['title_english']).reset_index(drop=True)
    pop_df.to_csv(pop_df_file)
pop_df

# %%
indices = []
for id in fav_df['mal_id']:
    index = pop_df[pop_df['mal_id']==id].index[0]
    indices.append(index)

# %%
mlb = MultiLabelBinarizer()
ml_df = pd.get_dummies(pop_df,columns=['rating'])
genres = pd.DataFrame(mlb.fit_transform(pop_df['genres'].apply(lambda x: ast.literal_eval(x))),columns=mlb.classes_)
studios = pd.DataFrame(mlb.fit_transform(pop_df['studios'].apply(lambda x: ast.literal_eval(x))),columns=mlb.classes_)
themes = pd.DataFrame(mlb.fit_transform(pop_df['themes'].apply(lambda x: ast.literal_eval(x))),columns=mlb.classes_)
demographics = pd.DataFrame(mlb.fit_transform(pop_df['demographics'].apply(lambda x: ast.literal_eval(x))),columns=mlb.classes_)
synopsis = pd.DataFrame(mlb.fit_transform(pop_df['synopsis'].apply(lambda x: ast.literal_eval(x))),columns=mlb.classes_)
dummy_df = pd.concat([ml_df,genres,studios,themes,demographics,synopsis], axis=1).drop(['score','popularity','mal_id','title_english','genres','studios','themes','demographics','synopsis'], axis=1).fillna(0)
dummy_df

# %%
normalizer = MinMaxScaler()
normal = normalizer.fit_transform(dummy_df)
normal_df = pd.DataFrame(data=normal,columns=dummy_df.columns)

# %%
n_clusters = 38
model = AgglomerativeClustering(n_clusters=n_clusters, compute_distances=True)
y = model.fit_predict(normal_df)

# %%
pop_df['cluster'] = y
display(pop_df.iloc[indices])
display(pop_df[pop_df['cluster']==30])
# Out:
#      mal_id                            title_english  score  popularity  \
# 217     813                            Dragon Ball Z   8.16         104
# 3      9253                              Steins;Gate   9.08          13
# 128   13601                              Psycho-Pass   8.34          58
# 1      5114         Fullmetal Alchemist: Brotherhood   9.11           3
# 171   49918                My Hero Academia Season 6   8.25         573
# 14     2904  Code Geass: Lelouch of the Rebellion R2   8.91          47
# 153      45                          Rurouni Kenshin   8.29         414
# 5     38524          Attack on Titan Season 3 Part 2   9.06          27
# 119    9756                Puella Magi Madoka Magica   8.36          94
# 80    30276                            One Punch Man   8.51           4
#
#                              rating  \
# 217       PG-13 - Teens 13 or older
# 3         PG-13 - Teens 13 or older
# 128  R - 17+ (violence & profanity)
# 1    R - 17+ (violence & profanity)
# 171       PG-13 - Teens 13 or older
# 14   R - 17+ (violence & profanity)
# 153       PG-13 - Teens 13 or older
# 5    R - 17+ (violence & profanity)
# 119       PG-13 - Teens 13 or older
# 80   R - 17+ (violence & profanity)
#
#                                            genres                    studios  \
# 217  ['Action', 'Adventure', 'Comedy', 'Fantasy']         ['Toei Animation']
# 3                 ['Drama', 'Sci-Fi', 'Suspense']              ['White Fox']
# 128              ['Action', 'Sci-Fi', 'Suspense']         ['Production I.G']
# 1     ['Action', 'Adventure', 'Drama', 'Fantasy']                  ['Bones']
# 171                                    ['Action']                  ['Bones']
# 14                  ['Action', 'Drama', 'Sci-Fi']                ['Sunrise']
# 153  ['Action', 'Adventure', 'Comedy', 'Romance']  ['Gallop', 'Studio Deen']
# 5                             ['Action', 'Drama']             ['Wit Studio']
# 119        ['Award Winning', 'Drama', 'Suspense']                  ['Shaft']
# 80                           ['Action', 'Comedy']               ['Madhouse']
#
#                                            themes demographics  \
# 217               ['Martial Arts', 'Super Power']  ['Shounen']
# 3                ['Psychological', 'Time Travel']           []
# 128  ['Adult Cast', 'Detective', 'Psychological']           []
# 1                                    ['Military']  ['Shounen']
# 171                     ['School', 'Super Power']  ['Shounen']
# 14           ['Mecha', 'Military', 'Super Power']           []
# 153                     ['Historical', 'Samurai']  ['Shounen']
# 5                ['Gore', 'Military', 'Survival']  ['Shounen']
# 119             ['Mahou Shoujo', 'Psychological']           []
# 80        ['Adult Cast', 'Parody', 'Super Power']   ['Seinen']
#
#                                               synopsis  cluster
# 217  ['annihilated', 'martial', 'balls', 'protect',...       25
# 3    ['ire', 'using', 'caused', 'meets', 'send', 'f...       22
# 128  ['criminal', 'signs', 'jaded', 'akane', 'known...       12
# 1    ['rewrite', 'exchange', 'winry', 'elric', 'alc...       37
# 171  ['intel', 'confirms', 'rages', 'criminal', 'un...       30
# 14   ['written', 'lost', 'group', 'accept', 'missin...        8
# 153  ['protecting', 'unmatched', 'kamiya', 'kaoru',...       29
# 5    ['arlert', 'sacrifices', 'countless', 'strive'...       23
# 119  ['sayaka', 'dreams', 'mal', 'madoka', 'kyuubey...       22
# 80   ['member', 'capable', 'pursue', 'heroes', 'ord...        7
#      mal_id                          title_english  score  popularity  \
# 22    37510                      Mob Psycho 100 II   8.81          79
# 47    50172                     Mob Psycho 100 III   8.66         505
# 81    30654  Assassination Classroom Second Season   8.50          85
# 88    32182                         Mob Psycho 100   8.49          33
# 168   50709                         Lycoris Recoil   8.25         671
# 171   49918              My Hero Academia Season 6   8.25         573
# 220   30503                       Noragami Aragoto   8.16          76
# 233    1604                                Reborn!   8.14         355
# 234   34572                           Black Clover   8.13          67
# 235   33486              My Hero Academia Season 2   8.13          14
# 255   24833                Assassination Classroom   8.09          35
# 277   36456              My Hero Academia Season 3   8.06          26
# 281    1559        KenIchi: The Mightiest Disciple   8.06         736
# 287   18679                           Kill la Kill   8.04          50
# 329      77        Magical Girl Lyrical Nanoha A's   7.97        2447
# 334   20507                               Noragami   7.96          24
# 358   38408              My Hero Academia Season 4   7.93          54
# 371   31964                       My Hero Academia   7.91           6
# 423    3588                             Soul Eater   7.84          59
# 482     154                            Shaman King   7.75         583
# 504   18153                    Beyond the Boundary   7.73         113
# 507     479                        The Law of Ueki   7.73        1680
# 624    1915   Magical Girl Lyrical Nanoha StrikerS   7.62        2728
# 654     132                             Getbackers   7.59        1622
# 665    5507                    Valkyria Chronicles   7.58        1518
# 669   24405                          World Trigger   7.58         519
# 676   27991                     K: Return of Kings   7.57         655
# 710   32681                    Space Patrol Luluco   7.55        1387
# 740   14131                       Girls und Panzer   7.52         751
# 754    9919                          Blue Exorcist   7.51          36
# 765   10588                Persona 4 the Animation   7.50         830
# 844   14467                                      K   7.44         233
#
#                         rating  \
# 22   PG-13 - Teens 13 or older
# 47   PG-13 - Teens 13 or older
# 81   PG-13 - Teens 13 or older
# 88   PG-13 - Teens 13 or older
# 168  PG-13 - Teens 13 or older
# 171  PG-13 - Teens 13 or older
# 220  PG-13 - Teens 13 or older
# 233  PG-13 - Teens 13 or older
# 234  PG-13 - Teens 13 or older
# 235  PG-13 - Teens 13 or older
# 255  PG-13 - Teens 13 or older
# 277  PG-13 - Teens 13 or older
# 281  PG-13 - Teens 13 or older
# 287  PG-13 - Teens 13 or older
# 329  PG-13 - Teens 13 or older
# 334  PG-13 - Teens 13 or older
# 358  PG-13 - Teens 13 or older
# 371  PG-13 - Teens 13 or older
# 423  PG-13 - Teens 13 or older
# 482  PG-13 - Teens 13 or older
# 504  PG-13 - Teens 13 or older
# 507  PG-13 - Teens 13 or older
# 624  PG-13 - Teens 13 or older
# 654  PG-13 - Teens 13 or older
# 665  PG-13 - Teens 13 or older
# 669  PG-13 - Teens 13 or older
# 676  PG-13 - Teens 13 or older
# 710  PG-13 - Teens 13 or older
# 740  PG-13 - Teens 13 or older
# 754  PG-13 - Teens 13 or older
# 765  PG-13 - Teens 13 or older
# 844  PG-13 - Teens 13 or older
#
#                                                 genres                studios  \
# 22                ['Action', 'Comedy', 'Supernatural']              ['Bones']
# 47                ['Action', 'Comedy', 'Supernatural']              ['Bones']
# 81                                ['Action', 'Comedy']             ['Lerche']
# 88                ['Action', 'Comedy', 'Supernatural']              ['Bones']
# 168                                         ['Action']       ['A-1 Pictures']
# 171                                         ['Action']              ['Bones']
# 220                              ['Action', 'Fantasy']              ['Bones']
# 233                               ['Action', 'Comedy']            ['Artland']
# 234                    ['Action', 'Comedy', 'Fantasy']            ['Pierrot']
# 235                                         ['Action']              ['Bones']
# 255                               ['Action', 'Comedy']             ['Lerche']
# 277                                         ['Action']              ['Bones']
# 281                               ['Action', 'Comedy']  ['TMS Entertainment']
# 287                      ['Action', 'Comedy', 'Ecchi']            ['Trigger']
# 329                      ['Action', 'Comedy', 'Drama']         ['Seven Arcs']
# 334                              ['Action', 'Fantasy']              ['Bones']
# 358                                         ['Action']              ['Bones']
# 371                                         ['Action']              ['Bones']
# 423                    ['Action', 'Comedy', 'Fantasy']              ['Bones']
# 482  ['Action', 'Adventure', 'Comedy', 'Supernatural']              ['Xebec']
# 504                              ['Action', 'Fantasy']    ['Kyoto Animation']
# 507            ['Action', 'Adventure', 'Supernatural']        ['Studio Deen']
# 624                      ['Action', 'Comedy', 'Drama']         ['Seven Arcs']
# 654  ['Action', 'Comedy', 'Drama', 'Mystery', 'Supe...        ['Studio Deen']
# 665                              ['Action', 'Romance']       ['A-1 Pictures']
# 669               ['Action', 'Sci-Fi', 'Supernatural']     ['Toei Animation']
# 676                         ['Action', 'Supernatural']            ['GoHands']
# 710                  ['Action', 'Adventure', 'Comedy']            ['Trigger']
# 740                                         ['Action']              ['Actas']
# 754                              ['Action', 'Fantasy']       ['A-1 Pictures']
# 765  ['Action', 'Adventure', 'Mystery', 'Sci-Fi', '...           ['AIC ASTA']
# 844              ['Action', 'Mystery', 'Supernatural']            ['GoHands']
#
#                                  themes demographics  \
# 22                      ['Super Power']           []
# 47                      ['Super Power']           []
# 81                           ['School']  ['Shounen']
# 88                      ['Super Power']           []
# 168                                  []           []
# 171           ['School', 'Super Power']  ['Shounen']
# 220                       ['Mythology']  ['Shounen']
# 233  ['Organized Crime', 'Super Power']  ['Shounen']
# 234                                  []  ['Shounen']
# 235           ['School', 'Super Power']  ['Shounen']
# 255                          ['School']  ['Shounen']
# 277           ['School', 'Super Power']  ['Shounen']
# 281          ['Martial Arts', 'School']  ['Shounen']
# 287           ['School', 'Super Power']           []
# 329     ['Mahou Shoujo', 'Super Power']           []
# 334                       ['Mythology']  ['Shounen']
# 358           ['School', 'Super Power']  ['Shounen']
# 371           ['School', 'Super Power']  ['Shounen']
# 423                          ['School']  ['Shounen']
# 482                     ['Super Power']  ['Shounen']
# 504                          ['School']           []
# 507                     ['Super Power']  ['Shounen']
# 624     ['Mahou Shoujo', 'Super Power']           []
# 654                     ['Super Power']  ['Shounen']
# 665                        ['Military']           []
# 669                          ['School']  ['Shounen']
# 676                     ['Super Power']           []
# 710                           ['Space']           []
# 740              ['Military', 'School']           []
# 754             ['Mythology', 'School']  ['Shounen']
# 765           ['School', 'Super Power']           []
# 844                     ['Super Power']           []
#
#                                               synopsis  cluster
# 22   ['strong', 'legends', 'anymore', 'tone', 'dark...       30
# 47   ['naivety', 'forward', 'assist', 'paranormal',...       30
# 81   ['works', 'hard', 'middle', 'head', 'prevent',...       30
# 88   ['order', 'change', 'realizes', 'young', 'grad...       30
# 168  ['unfortunately', 'belonged', 'number', 'situa...       30
# 171  ['intel', 'confirms', 'rages', 'criminal', 'un...       30
# 220  ['normal', 'hopes', 'cheerily', 'prepares', 'd...       30
# 233  ['classmates', 'rewrite', 'idol', 'reborn', 'f...       30
# 234  ['tries', 'magic', 'power', 'wizard', 'clover'...       30
# 235  ['pitted', 'disrupt', 'sharp', 'midoriya', 'ac...       30
# 255  ['threatened', 'advancing', 'like', 'nagisa', ...       30
# 277  ['superheroes', 'izuku', 'deku', 'camp', 'hero...       30
# 281  ['fight', 'class', 'martial', 'arts', 'fighter...       30
# 287  ['clothes', 'father', 'school', 'murder', 'aca...       30
# 329  ['bureau', 'proves', 'video', 'intelligent', '...       30
# 334  ['place', 'turning', 'iki', 'just', 'number', ...       30
# 358  ['criminal', 'shigaraki', 'league', 'villain',...       30
# 371  ['months', 'chosen', 'prestigious', 'wanted', ...       30
# 423  ['world', 'wielder', 'eater', 'academy', 'meis...       30
# 482  ['begin', 'reshape', 'new', 'world', 'fight', ...       30
# 504  ['human', 'form', 'warriors', 'powerful', 'blo...       30
# 507  ['world', 'ueki', 'power', 'candidates', 'stud...       30
# 624  ['shoujo', 'crew', 'rest', 'bureau', 'erio', '...       30
# 654  ['success', 'pair', 'broke', 'matter', 'actual...       30
# 665  ['border', 'retreating', 'younger', 'jump', 'f...       30
# 669  ['known', 'osamu', 'members', 'neighbor', 'stu...       30
# 676  ['losses', 'possible', 'threat', 'homra', 'kin...       30
# 710  ['intergalactic', 'way', 'suit', 'justice', 's...       30
# 740  ['sport', 'world', 'program', 'form', 'miho', ...       30
# 754  ['king', 'conquer', 'demon', 'possession', 'de...       30
# 765  ['hostile', 'midnight', 'school', 'channel', '...       30
# 844  ['video', 'appear', 'bringing', 'unraveling', ...       30

# %%
# xresults = jikan.search('anime', 'full metal alechmist: brotherhood')
# print(xresults)
# xdf = pd.DataFrame(xresults['data'])
# for col in xdf.columns:
#     print(col)
#     display(xdf[col])
from anime_clusters import get_cluster
df = get_cluster('Steins;Gate')
df
# Out:
#      mal_id                                      title_english  score  \
# 3      9253                                        Steins;Gate   9.08
# 12     4181                               Clannad: After Story   8.94
# 44    33352                                  Violet Evergarden   8.67
# 79    30484                                      Steins;Gate 0   8.52
# 107   37965                                  Run with the Wind   8.40
# 119    9756                          Puella Magi Madoka Magica   8.36
# 125   39247                     Miss Kobayashi's Dragon Maid S   8.34
# 126      30                            Neon Genesis Evangelion   8.34
# 130     338                             The Rose of Versailles   8.33
# 137    5420                              The Beast Player Erin   8.32
# 207     440                           Revolutionary Girl Utena   8.19
# 236     721                                      Princess Tutu   8.13
# 251   34076                             The Eccentric Family 2   8.10
# 280     237                                       Eureka Seven   8.06
# 293   42923                                   SK8 the Infinity   8.03
# 298    6211                                Tokyo Magnitude 8.0   8.02
# 301    4789                           ef - a tale of melodies.   8.01
# 307    2167                                            Clannad   8.00
# 313   16067                                  A Lull in the Sea   7.99
# 319   31173                     Snow White with the Red Hair 2   7.98
# 323   33206                       Miss Kobayashi's Dragon Maid   7.98
# 331     387                                     Haibane Renmei   7.97
# 338    1530                                              Kanon   7.96
# 340    5678                                            Kobato.   7.95
# 368   27775                                   Plastic Memories   7.91
# 372    9289              Hanasaku Iroha: Blossoms for Tomorrow   7.91
# 374     427                                       Kaleido Star   7.91
# 378   32995                                     Yuri!!! On ICE   7.90
# 384    2924                           ef - a tale of memories.   7.90
# 400   37435                                   Carole & Tuesday   7.88
# 425   17909                               The Eccentric Family   7.84
# 472   30123                       Snow White with the Red Hair   7.76
# 553   33502  WorldEnd: What do you do at the end of the wor...   7.68
# 573   34284       Yuki Yuna is a Hero: The Washio Sumi Chapter   7.67
# 574   34445              Yuki Yuna is a Hero: The Hero Chapter   7.66
# 646    1699                                     Romeo x Juliet   7.60
# 735   36754            Kakuriyo: Bed and Breakfast for Spirits   7.53
# 761   46093                         The Aquatope on White Sand   7.51
# 772   50248                     Birdie Wing: Golf Girls' Story   7.49
# 791     587                        Looking Up At The Half-Moon   7.48
# 805   22147                               Amagi Brilliant Park   7.47
# 846   40904                                   Remake Our Life!   7.43
#
#      popularity                     rating  \
# 3            13  PG-13 - Teens 13 or older
# 12          108  PG-13 - Teens 13 or older
# 44           51  PG-13 - Teens 13 or older
# 79          191  PG-13 - Teens 13 or older
# 107         769  PG-13 - Teens 13 or older
# 119          94  PG-13 - Teens 13 or older
# 125         398  PG-13 - Teens 13 or older
# 126          46  PG-13 - Teens 13 or older
# 130        1986  PG-13 - Teens 13 or older
# 137        2080  PG-13 - Teens 13 or older
# 207        1049  PG-13 - Teens 13 or older
# 236        1300  PG-13 - Teens 13 or older
# 251        2495  PG-13 - Teens 13 or older
# 280         462  PG-13 - Teens 13 or older
# 293         399  PG-13 - Teens 13 or older
# 298         746  PG-13 - Teens 13 or older
# 301        1283  PG-13 - Teens 13 or older
# 307          78  PG-13 - Teens 13 or older
# 313         333  PG-13 - Teens 13 or older
# 319         612  PG-13 - Teens 13 or older
# 323         105  PG-13 - Teens 13 or older
# 331         804  PG-13 - Teens 13 or older
# 338         805  PG-13 - Teens 13 or older
# 340        1285  PG-13 - Teens 13 or older
# 368         164  PG-13 - Teens 13 or older
# 372         649  PG-13 - Teens 13 or older
# 374        2089  PG-13 - Teens 13 or older
# 378         182  PG-13 - Teens 13 or older
# 384         850  PG-13 - Teens 13 or older
# 400         684  PG-13 - Teens 13 or older
# 425        1286  PG-13 - Teens 13 or older
# 472         290  PG-13 - Teens 13 or older
# 553         550  PG-13 - Teens 13 or older
# 573        3063  PG-13 - Teens 13 or older
# 574        3190  PG-13 - Teens 13 or older
# 646        1168  PG-13 - Teens 13 or older
# 735        1366  PG-13 - Teens 13 or older
# 761        1328  PG-13 - Teens 13 or older
# 772        3197  PG-13 - Teens 13 or older
# 791        1865  PG-13 - Teens 13 or older
# 805         296  PG-13 - Teens 13 or older
# 846         723  PG-13 - Teens 13 or older
#
#                                                 genres  \
# 3                      ['Drama', 'Sci-Fi', 'Suspense']
# 12                ['Drama', 'Romance', 'Supernatural']
# 44                                ['Drama', 'Fantasy']
# 79                     ['Drama', 'Sci-Fi', 'Suspense']
# 107                                ['Drama', 'Sports']
# 119             ['Award Winning', 'Drama', 'Suspense']
# 125                       ['Fantasy', 'Slice of Life']
# 126  ['Action', 'Avant Garde', 'Award Winning', 'Dr...
# 130                               ['Drama', 'Romance']
# 137              ['Drama', 'Fantasy', 'Slice of Life']
# 207          ['Comedy', 'Drama', 'Fantasy', 'Mystery']
# 236  ['Comedy', 'Drama', 'Fantasy', 'Mystery', 'Rom...
# 251    ['Comedy', 'Drama', 'Fantasy', 'Slice of Life']
# 280        ['Adventure', 'Drama', 'Romance', 'Sci-Fi']
# 293                                         ['Sports']
# 298                         ['Award Winning', 'Drama']
# 301    ['Drama', 'Mystery', 'Romance', 'Supernatural']
# 307               ['Drama', 'Romance', 'Supernatural']
# 313                    ['Drama', 'Fantasy', 'Romance']
# 319                    ['Drama', 'Fantasy', 'Romance']
# 323                       ['Fantasy', 'Slice of Life']
# 331   ['Drama', 'Fantasy', 'Mystery', 'Slice of Life']
# 338  ['Drama', 'Romance', 'Slice of Life', 'Superna...
# 340          ['Comedy', 'Drama', 'Fantasy', 'Romance']
# 368                     ['Drama', 'Romance', 'Sci-Fi']
# 372                                          ['Drama']
# 374                     ['Comedy', 'Drama', 'Fantasy']
# 378                        ['Award Winning', 'Sports']
# 384                    ['Drama', 'Mystery', 'Romance']
# 400                                ['Drama', 'Sci-Fi']
# 425  ['Award Winning', 'Comedy', 'Drama', 'Fantasy'...
# 472                    ['Drama', 'Fantasy', 'Romance']
# 553          ['Drama', 'Fantasy', 'Romance', 'Sci-Fi']
# 573              ['Drama', 'Fantasy', 'Slice of Life']
# 574              ['Drama', 'Fantasy', 'Slice of Life']
# 646                    ['Drama', 'Fantasy', 'Romance']
# 735         ['Drama', 'Fantasy', 'Gourmet', 'Romance']
# 761                         ['Drama', 'Slice of Life']
# 772                                         ['Sports']
# 791                     ['Comedy', 'Drama', 'Romance']
# 805                     ['Comedy', 'Drama', 'Fantasy']
# 846              ['Drama', 'Romance', 'Slice of Life']
#
#                                 studios  \
# 3                         ['White Fox']
# 12                  ['Kyoto Animation']
# 44                  ['Kyoto Animation']
# 79                        ['White Fox']
# 107                  ['Production I.G']
# 119                           ['Shaft']
# 125                 ['Kyoto Animation']
# 126  ['Gainax', 'Tatsunoko Production']
# 130             ['Tokyo Movie Shinsha']
# 137    ['Production I.G', 'Trans Arts']
# 207                       ['J.C.Staff']
# 236                  ['Hal Film Maker']
# 251                      ['P.A. Works']
# 280                           ['Bones']
# 293                           ['Bones']
# 298          ['Bones', 'Kinema Citrus']
# 301                           ['Shaft']
# 307                 ['Kyoto Animation']
# 313                      ['P.A. Works']
# 319                           ['Bones']
# 323                 ['Kyoto Animation']
# 331                           ['Radix']
# 338                 ['Kyoto Animation']
# 340                        ['Madhouse']
# 368                       ['Doga Kobo']
# 372                      ['P.A. Works']
# 374                           ['Gonzo']
# 378                           ['MAPPA']
# 384                           ['Shaft']
# 400                           ['Bones']
# 425                      ['P.A. Works']
# 472                           ['Bones']
# 553                ['Satelight', 'C2C']
# 573                   ['Studio Gokumi']
# 574                   ['Studio Gokumi']
# 646                           ['Gonzo']
# 735                           ['Gonzo']
# 761                      ['P.A. Works']
# 772           ['Bandai Namco Pictures']
# 791                       ['Group TAC']
# 805                 ['Kyoto Animation']
# 846                           ['feel.']
#
#                                     themes demographics  \
# 3         ['Psychological', 'Time Travel']           []
# 12                                      []           []
# 44                                      []           []
# 79                         ['Time Travel']           []
# 107                         ['Adult Cast']           []
# 119      ['Mahou Shoujo', 'Psychological']           []
# 125                                     []           []
# 126             ['Mecha', 'Psychological']           []
# 130             ['Historical', 'Military']   ['Shoujo']
# 137                                     []           []
# 207      ['Mahou Shoujo', 'Psychological']           []
# 236    ['Mahou Shoujo', 'Performing Arts']           []
# 251                          ['Mythology']           []
# 280                              ['Mecha']           []
# 293                                     []           []
# 298                                     []           []
# 301                                     []           []
# 307                             ['School']           []
# 313                       ['Love Polygon']           []
# 319                                     []   ['Shoujo']
# 323                                     []           []
# 331                      ['Psychological']           []
# 338                                     []           []
# 340                          ['Iyashikei']           []
# 368                                     []           []
# 372                          ['Workplace']           []
# 374                    ['Performing Arts']           []
# 378                                     []           []
# 384                                     []           []
# 400                              ['Music']           []
# 425                          ['Mythology']           []
# 472                                     []   ['Shoujo']
# 553                                     []           []
# 573                       ['Mahou Shoujo']           []
# 574                       ['Mahou Shoujo']           []
# 646                         ['Historical']           []
# 735  ['Adult Cast', 'Isekai', 'Mythology']    ['Josei']
# 761                          ['Workplace']           []
# 772                                     []           []
# 791                                     []           []
# 805                          ['Workplace']           []
# 846          ['Adult Cast', 'Time Travel']           []
#
#                                               synopsis  cluster
# 3    ['ire', 'using', 'caused', 'meets', 'send', 'f...       22
# 12   ['produced', 'winter', 'graduate', 'purpose', ...       22
# 44   ['written', 'guardian', 'new', 'memory', 'work...       22
# 79   ['college', 'person', 'time', 'forum', 'simula...       22
# 107  ['unfortunately', 'involved', 'ekiden', 'stude...       22
# 119  ['sayaka', 'dreams', 'mal', 'madoka', 'kyuubey...       22
# 125  ['radical', 'intrigued', 'maid', 'life', 'day'...       22
# 126  ['known', 'year', 'despite', 'evangelion', 'ge...       22
# 130  ['alliance', 'men', 'revered', 'impoverished',...       22
# 137  ['shin', 'tensions', 'war', 'army', 'mother', ...       22
# 207  ['himemiya', 'council', 'emblem', 'student', '...       22
# 236  ['mal', 'cats', 'reality', 'heart', 'tutu', 'p...       22
# 251  ['son', 'turn', 'yasaburou', 'brothers', 'ripp...       22
# 280  ['insistence', 'eureka', 'trapar', 'riding', '...       22
# 293  ['runs', 'dangerous', 'trouble', 'money', 'ska...       22
# 298  ['frustration', 'apart', 'come', 'return', 'yu...       22
# 301  ['kuze', 'man', 'girl', 'yuu', 'closer', 'atte...       22
# 307  ['away', 'learns', 'life', 'exclaims', 'dull',...       22
# 313  ['change', 'personal', 'hatred', 'hikari', 'fr...       22
# 319  ['confirmed', 'way', 'named', 'tanbarun', 'her...       22
# 323  ['personal', 'efficient', 'home', 'girl', 'new...       22
# 331  ['dream', 'world', 'old', 'cocoon', 'memories'...       22
# 338  ['rewrite', 'comes', 'past', 'befriends', 'con...       22
# 340  ['brighten', 'situations', 'desire', 'various'...       22
# 368  ['hostile', 'responsible', 'isla', 'giftia', '...       22
# 372  ['maid', 'collectors', 'run', 'away', 'small',...       22
# 374  ['mal', 'california', 'written', 'heights', 'n...       22
# 378  ['figure', 'accepts', 'performing', 'closing',...       22
# 384  ['renji', 'miyako', 'kei', 'shindou', 'girl', ...       22
# 400  ['fateful', 'advancements', 'perform', 'carole...       22
# 425  ['alongside', 'painful', 'coming', 'killed', '...       22
# 472  ['hime', 'raji', 'red', 'life', 'clarines', 't...       22
# 553  ['humans', 'battle', 'young', 'weapons', 'ones...       22
# 573  ['gin', 'appearance', 'paying', 'chosen', 'son...       22
# 574  ['notice', 'desperate', 'swing', 'lost', 'girl...       22
# 646  ['heir', 'hidden', 'entire', 'juliet', 'capule...       22
# 735  ['ability', 'pay', 'cooking', 'debt', 'spirits...       22
# 761  ['finds', 'end', 'lack', 'director', 'doors', ...       22
# 772  ['defeat', 'known', 'bright', 'prodigy', 'writ...       22
# 791  ['budding', 'putting', 'friends', 'away', 'cap...       22
# 805  ['stipulated', 'feet', 'date', 'sento', 'use',...       22
# 846  ['eiko', 'platinum', 'game', 'life', 'pursue',...       22
